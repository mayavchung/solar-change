# %% [markdown]
# # Calculate the feedbacks in single model abrupt Solar change experiments by using the radiative kernel
#
# # Reference: 50 year running mean
#
# ## GFDL model version
#
# >ref: [Soden, et.al., (2008)](https://doi.org/10.1175/2007JCLI2110.1)
#
# Original code written by Chenggong Wang
# > Available on [Github](https://github.com/ChenggongWang/Radiative_Response_with_Radiative_Kernel)
#
# Modified by Maya V. Chung Aug 6 2025 to calculate cloud feedback explicitly

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import subprocess 
import time
from scipy import stats
sstart_time0 = time.time()
import netCDF4

# %%
# import the function as r3k 
import Radiative_Response_with_Radiative_kernel_cloud as r3k
r3k.compile_njit_functions()
# Out:
# @njit Functions compiling ...  | finished!

# %% [markdown]
# # Data required and preprocess
#
# - 10 Monthly mean variables [CMIP6 standard output](https://pcmdi.llnl.gov/mips/cmip3/variableList.html):
# `ta, hus, ts, rlut, rsdt, rsut, rsutcs, rlutcs, rsus, rsds`
#
# - Control (12 month climatology) and Perturbation (nx12 monthly data) data are need.
# If you have already computed anomaly data, create a control data filled with zeros
# - `ta` and `hus` are 4d `(time, plev, lat, lon)` variables, while others are 3d `(time, lat, lon)` variables.
# `time` should be nx12 month (n years >= 1 year).
#
# - __Since data and kernel are discrete, we need regrid them to the same resolution.__
# My practice: bring(regrid) the data to kernels.

# %% [markdown]
# # functions

# %%
def get_years(expname):
    import re
    import os
    
    # Directory containing your files
    directory = f"./{model}_regridded/"
    
    # Substring to search for
    partial_name = expname
    
    # Loop through files in the directory
    for file_name in os.listdir(directory):
        if partial_name in file_name:
            # Search for the '0101-1187' pattern
            match = re.search(r"\d{4}-\d{4}", file_name)
            if match:
                year_range = match.group()
            else:
                print(f"File: {file_name}, Year range not found.")

    return year_range

### get the years for loading in files later ###

# %%
def load_4D_var(var, model, exp, CTRLexp):

    pert_files = f"./temp_4D_{model}/{var}.{exp}.mon.*.nc.2x2.5"
    pert_ds = xr.open_mfdataset(pert_files, combine="by_coords", parallel=False) # parallel = True
    
    CTRL_files = f"./temp_4D_{model}/{var}.{CTRLexp}.mon.*.nc.2x2.5"
    CTRL_ds = xr.open_mfdataset(CTRL_files, combine="by_coords", parallel=False) # parallel = True

    pert_da = pert_ds["__xarray_dataarray_variable__"].rename(var) # rename, there was some error with the loading variable name
    CTRL_da = CTRL_ds["__xarray_dataarray_variable__"].rename(var)

    return pert_da, CTRL_da

# %%
def exp_to_pctstring(exp):
    # Dictionary to map patterns to their corresponding percent strings
    pattern_map = {
        'p6': '+6', 'm6': '-6',
        'p4': '+4', 'm4': '-4',
        'p2': '+2', 'm2': '-2',
        'p1': '+1', 'm1': '-1'
    }
    
    # Check each pattern in the dictionary and return the corresponding percent string
    for pattern, pctstring in pattern_map.items():
        if pattern in exp:
            return pctstring
    
    return None  # Return None if no match is found

# %% [markdown]
# ### function for reading in control and experiment data

# %%
def read_postprocessed_data(model,exp,CTRLexp):
    """
    This function reads and processes the data.
    The required variables are: ta hus ts rlut rsdt rsut rlutcs rsutcs rsus rsds, which in CMIP6 standard name (ref: https://pcmdi.llnl.gov/mips/cmip3/variableList.html#overview)

    Return:
        var_cont: dict of variables (monthly data of the control experiment. dim: [month,plev,lat,lon], time.size=yearx12)
        var_pert: dict of variables (monthly data of the perturbation experiment. dim: [time,plev,lat,lon], time.size=yearx12) 
    """
    # CMIP6 standard name, 
    # ref: https://pcmdi.llnl.gov/mips/cmip3/variableList.html#overview
    
    #var_list = 'ta hus ts rlut rsdt rsut rlutcs rsutcs rsus rsds'.split()
    var_list        = "temp sphum t_surf olr  swdn_toa swup_toa olr_clr swup_toa_clr swup_sfc swdn_sfc ".split()
    var_list_rename = "ta   hus   ts     rlut rsdt     rsut     rlutcs  rsutcs       rsus     rsds     ".split()
        
    var_cont = {} # control data in a dictionary {var1: DataArray,...} 
    var_pert = {} # perturbation data in a dictionary {var1: DataArray,...} 
    
    for i, var in enumerate(var_list): 

        if var == 'temp' or var == 'sphum':
            # load the chunked interpolated data
            da_pert, da_cont = load_4D_var(var, model, exp, CTRLexp)
            
            # rename vertical coordinate to plev
            da_pert = da_pert.rename({'pfull': 'plev'})
            da_pert.coords['plev'].attrs['units'] = 'mb'
            
            da_cont = da_cont.rename({'pfull': 'plev'})
            da_cont.coords['plev'].attrs['units'] = 'mb'
            
        else:
            pertyears = get_years(exp)
            CTRLyears = get_years(CTRLexp)
            
            filepath = f"./{model}_regridded/{var}.{CTRLexp}.mon.{CTRLyears}.nc.2x2.5" # for all time control reference
            da_cont =  xr.open_dataarray(filepath, engine='netcdf4')

            filepath = f"./{model}_regridded/{var}.{exp}.mon.{pertyears}.nc.2x2.5"
            da_pert = xr.open_dataarray(filepath, engine='netcdf4')

        # subset the control to the perturbation experiment years
        if da_cont.time.size > da_pert.time.size:
            da_cont = da_cont.isel(time=slice(0,da_pert.time.size))
            
        var_cont[var_list_rename[i]] =  da_cont #ds.rename({var: var_list_rename[i]}).load()
        var_pert[var_list_rename[i]] =  da_pert #.rename({var: var_list_rename[i]}).load()
    
    # return processed data 
    return var_cont, var_pert

# read kernel data
def read_kernel_file(rk_source='GFDL'):
    rkpath = "./radiative_kernels/kernels_TOA_"+rk_source+"_CMIP6-standard.nc"
    f_RK =  xr.open_dataset(rkpath,decode_times=False) 
    if rk_source =='GFDL':
        f_RK =  f_RK.rename({'time': 'month'})
        f_RK.coords['month'] = np.arange(1,13,1)
    return f_RK

# %% [markdown]
# ### Function for decomposing the radiative response with radiative kernels
# * Relative to Control climatology calculated over 50 years in a running window updated every 5 years
# * Saves to netcdf in 50-year chunks (~1 GB, 2-3 minutes each)

# %%
def decomp_rk_window_clim_save(new_RK,var_pert,var_cont,model,exp,CTRLexp):

    years = np.unique(var_pert['ta'].time.dt.year)  # ex. array([ 101,  102,  103, ..., 1998, 1999, 2000])
    pctstring = exp_to_pctstring(exp)
    chunk_size = 50

    print(years)
    
    # for progress tracker
    import time
    #from IPython.display import clear_output
    
    # Iterate over the years
    for i in range(0, len(years), chunk_size):     #for i in range(len(years)):
    
        appended_dict = {} # reset the list that the data is saved in
        start_time = time.time()
        
        start_year = years[i] # get start year of chunk (101, 201, etc.)
        end_year = years[i] + chunk_size - 1 # get end year of chunk (150, 200, 250, etc.)
        print(f'Start year: {start_year}')
    
        import os
        import glob
        
        # Define the file path pattern with a wildcard for the unknown end_year
        file_pattern = f'./rk_decomp_cloud/rk.decomp.{model}.{pctstring}%solar.50yrref.{start_year}-*.nc'
        
        # Use glob to search for matching files
        matching_files = glob.glob(file_pattern)
        
        if matching_files:  # If there are any matches
            print(f'Already exists: {matching_files}')
            continue
        else:
            print('computing...')

        # check if the file exists
        
        for iyear in range(i,i+chunk_size):
            #print(iyear) # debugging
            
            # stop if end of run does not align with chunk size
            if iyear >= np.size(years):
                continue
            
            current_year = years[iyear]
            print(f'Current year: {current_year}')
            
            #var_pert_temp = {key: da.isel(time=slice(i*12,i*12+12)) for key, da in var_pert.items()} # get that year's perturbation data
            var_pert_temp = {key: da.isel(time=slice(iyear*12,iyear*12+12)) for key, da in var_pert.items()} # get that year's perturbation data
    
            # Define the 50-year running window for the control experiment
            if current_year >= years[0] + 25 and current_year <= years[-1] - 25:
                # compute and update every 5 years
                if iyear % 5 == 0:
                    var_cont_mean = {key: da.isel(time=slice((iyear-25)*12, (iyear+25)*12)).groupby('time.month').mean(dim='time') for key, da in var_cont.items()}
                else:
                    pass # don't re-calculate mean
            
            elif current_year < years[0] + 25:
                # Use the average of the first 50 years
                if current_year == years[0]:
                    var_cont_mean = {key: da.isel(time=slice(0,50*12)).groupby('time.month').mean(dim='time') for key, da in var_cont.items()}
                else:
                    pass # don't re-calculate mean
            
            elif current_year >= years[-1] - 25 + 1:
                # Use the average of the last 50 years
                #if current_year == years[-1] - 25 + 1:
                var_cont_mean = {key: da.isel(time=slice(-50*12,None)).groupby('time.month').mean(dim='time') for key, da in var_cont.items()}
                #else:
                #    pass # don't re-calculate mean
            
            # Compute the difference between the perturbation and the running mean
            ds_rk =  r3k.decompose_dR_rk_toa_core(var_pert_temp,
                                                       var_cont_mean, # 12-month climatology calculated over window
                                                       new_RK) # use the interpolated kernel
            
            # Append the result to the list
            if not appended_dict:
                appended_dict = ds_rk  # Initialize with the first result
            else:
                appended_dict = {key: xr.concat([appended_dict[key], ds_rk[key]], dim='time') for key in appended_dict}
            
        # save the dict
        yr1, yr2 = int(appended_dict['dR_rh_lw'].time.dt.year.min()), int(appended_dict['dR_rh_lw'].time.dt.year.max())
        fileo = f'./rk_decomp_cloud/rk.decomp.{model}.{pctstring}%solar.50yrref.{yr1}-{yr2}.nc'
        xr.Dataset(appended_dict).to_netcdf(fileo)
        print(f'saved {fileo}')
    
        elapsed_time = (time.time() - start_time) / 60
        print(f"Elapsed time: {elapsed_time:.2f} minutes")
        
    # Combine the list into a DataArray
    #running_diff = xr.concat(running_diff, dim='time')

# %% [markdown]
# # main section

# %%
def get_exps(model):
    if model == 'FLOR':
        exp = [
            'm6p0sol_CTL1860_tigercpu_intelmpi_18_576PE',
            'm4p0sol_CTL1860_tigercpu_intelmpi_18_576PE',
            'm2p0sol_CTL1860_tigercpu_intelmpi_18_576PE',
            'm1p0sol_CTL1860_tigercpu_intelmpi_18_576PE',
            'p1p0sol_CTL1860_tigercpu_intelmpi_18_576PE',
            'p2p0sol_CTL1860_tigercpu_intelmpi_18_576PE',
            'p4p0sol_CTL1860_tigercpu_intelmpi_18_576PE',
            'p6p0sol_CTL1860_tigercpu_intelmpi_18_576PE'
        ]
        CTRLexp = 'CTL1860_newdiag_tigercpu_intelmpi_18_576PE'
        
    elif model == 'CM2.1p1':
        exp = [
            'CTL1860_m6pctSolar_tigercpu_intelmpi_18_80PE',
            'CTL1860_m4pctSolar_tigercpu_intelmpi_18_80PE',
            'CTL1860_m2pctSolar_tigercpu_intelmpi_18_80PE',
            'CTL1860_m1pctSolar_tigercpu_intelmpi_18_80PE',
            'CTL1860_p1pctSolar_tigercpu_intelmpi_18_80PE',
            'CTL1860_p2pctSolar_tigercpu_intelmpi_18_80PE',
            'CTL1860_p4pctSolar_tigercpu_intelmpi_18_80PE',
            'CTL1860_p6pctSolar_tigercpu_intelmpi_18_80PE',
        ]
        CTRLexp = 'CTL1860_tigercpu_intelmpi_18_80PE'

    return exp, CTRLexp

# %%
f_RK =  read_kernel_file('GFDL') # read in kernel file

# %%
# each 50-year chunk ~2.5 min each

models = ['FLOR','CM2.1p1'] 

for model in models:

    experiments, CTRLexp = get_exps(model)

    for exp in experiments:

        print(model, exp)
        
        ##### read data in; control, perturbation #####
        print('reading in data...')
        var_cont, var_pert = read_postprocessed_data(model, exp, CTRLexp)
        
        #print(var_cont['ta'].shape)
        
        ##### interpolate vertical levels (kernel --> data) #####
        plev_ori = f_RK.coords['plev']
        plev_solar = var_pert['ta'].plev.values
        plev_solar = np.asanyarray(plev_solar)
        #print(plev_solar,plev_ori)
        
        # interpolate data onto the plev grid
        print('interpolating...')
        new_RK=f_RK.interp(plev=plev_solar)
        
        # # check interpolation with plots 
        # new_RK.lw_ta.mean(dim=['month','lon']).plot(cmap=plt.cm.jet, levels=np.arange(-0.6,0,0.05),figsize=(3,3))
        # f_RK.lw_ta.mean(dim=['month','lon']).plot(cmap=plt.cm.jet, levels=np.arange(-0.6,0,0.05),figsize=(3,3))

        print('decomposing with radiative kernel...')
        decomp_rk_window_clim_save(new_RK,var_pert,var_cont,model,exp,CTRLexp)
# Out:
# FLOR m6p0sol_CTL1860_tigercpu_intelmpi_18_576PE
# reading in data...
# interpolating...
# decomposing with radiative kernel...
# [101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118
#  119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 134 135 136
#  137 138 139 140 141 142 143 144 145 146 147 148 149 150 151 152 153 154
#  155 156 157 158 159 160 161 162 163 164 165 166 167 168 169 170 171 172
#  173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190
#  191 192 193 194 195 196 197 198 199 200 201 202 203 204 205 206 207 208
#  209 210 211 212 213 214 215 216 217 218 219 220 221 222 223 224 225 226
#  227 228 229 230 231 232 233 234 235 236 237 238 239 240 241 242 243 244
#  245 246 247 248 249 250 251 252 253 254 255 256 257 258 259 260 261 262
#  263 264 265 266 267 268 269 270 271 272 273 274 275 276 277 278 279 280
#  281 282 283 284 285 286 287 288 289 290 291 292 293 294 295 296 297 298
#  299 300 301 302 303 304 305 306 307 308 309 310 311 312 313 314 315 316
#  317 318 319 320 321 322 323 324 325 326 327 328 329 330 331 332 333 334
#  335 336 337 338 339 340 341 342 343 344 345 346 347 348 349 350 351 352
#  353 354 355 356 357 358 359 360 361 362 363 364 365 366 367 368 369 370
#  371 372 373 374 375 376 377 378 379 380 381 382 383 384 385 386 387 388
#  389 390 391 392 393 394 395 396 397 398 399 400 401 402 403 404 405 406
#  407 408 409 410 411 412 413 414 415 416 417 418 419 420 421 422 423 424
#  425 426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442
#  443 444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460
#  461 462 463 464 465 466 467 468 469 470 471 472 473 474 475 476 477 478
#  479 480 481 482 483 484 485 486 487 488 489 490 491 492 493 494 495 496
#  497 498 499 500 501 502 503 504 505 506 507 508 509 510 511 512 513 514
#  515 516 517 518 519 520 521 522 523 524 525 526 527 528 529 530 531 532
#  533 534 535 536 537 538 539 540 541 542 543 544 545 546 547 548 549 550
#  551 552 553 554 555 556 557 558 559 560 561 562 563 564 565 566 567 568
#  569 570 571 572 573 574 575 576 577 578 579 580 581 582 583 584 585 586
#  587 588 589 590 591 592 593 594 595 596 597]
# Start year: 101
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.101-150.nc']
# Start year: 151
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.151-200.nc']
# Start year: 201
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.201-250.nc']
# Start year: 251
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.251-300.nc']
# Start year: 301
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.301-350.nc']
# Start year: 351
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.351-400.nc']
# Start year: 401
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.401-450.nc']
# Start year: 451
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.451-500.nc']
# Start year: 501
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.501-550.nc']
# Start year: 551
# Already exists: ['./rk_decomp_cloud/rk.decomp.FLOR.-6%solar.50yrref.551-597.nc']
# FLOR m4p0sol_CTL1860_tigercpu_intelmpi_18_576PE
# reading in data...
# interpolating...
# decomposing with radiative kernel...
# [ 101  102  103 ... 1185 1186 1187]
# Start year: 101
# computing...
# Current year: 101
# Current year: 102
# Current year: 103
# Current year: 104
# Current year: 105
# Current year: 106
# Current year: 107
# Current year: 108
# Current year: 109
# Current year: 110
# Current year: 111
# Current year: 112
# Current year: 113
# Current year: 114
# Current year: 115
# Current year: 116
# Current year: 117
# Current year: 118
# Current year: 119
# Current year: 120
# Current year: 121
# Current year: 122
# Current year: 123
# Current year: 124
# Current year: 125
# Current year: 126
# Current year: 127
# Current year: 128
# Current year: 129
# Current year: 130
# Current year: 131
# Current year: 132
# Current year: 133
# Current year: 134
# Current year: 135
# Current year: 136
# Current year: 137
# Current year: 138
# Current year: 139
# Current year: 140
# Current year: 141
# Current year: 142
# Current year: 143
# Current year: 144
# Current year: 145
# Current year: 146
# Current year: 147
# Current year: 148
# Current year: 149
# Current year: 150
# saved ./rk_decomp_cloud/rk.decomp.FLOR.-4%solar.50yrref
# Current year: 185
# Current year: 186
# Current year: 187
# Current year: 188
# Current year: 189
# Current year: 190
# Current year: 191
# Current year: 192
# Current year: 193
# Current year: 194
# Current year: 195
# Current year: 196
# Current year: 197
# Current year: 198
# Current year: 199
# Current year: 200
# saved ./rk_decomp_cloud/rk.decomp.CM2.1p1.+1%solar.50yrref.151-200.nc
# Elapsed time: 2.98 minutes
# Start year: 201
# computing...
# Current year: 201
# Current year: 202
# Current year: 203
# Current year: 204
# Current year: 205
# Current year: 206
# Current year: 207
# Current year: 208
# Current year: 209
# Current year: 210
# Current year: 211
# Current year: 212
# Current year: 213
# Current year: 214
# Current year: 215
# Current year: 216
# Current year: 217
# Current year: 218
# Current year: 219
# Current year: 220
# Current year: 221
# Current year: 222
# Current year: 223
# Current year: 224
# Current year: 225
# Current year: 226
# Current year: 227
# Current year: 228
# Current year: 229
# Current year: 230
# Current year: 231
# Current year: 232
# Current year: 233
# Current year: 234
# Current year: 235
# Current year: 236
# Current year: 237
# Current year: 238
# Current year: 239
# Current year: 240
# Current year: 241
# Current year: 242
# Current year: 243
# Current year: 244
# Current year: 245
# Current year: 246
# Current year: 247
# Current year: 248
# Current year: 249
# Current year: 250
# saved ./rk_decomp_cloud/rk.decomp.CM2.1p1.+1%solar.50yrref.201-250.nc
# Elapsed time: 2.85 minutes
# Start year: 251
# computing...
# Current year: 251
# Current year: 252
# Current year: 253
# Current year: 254
# Current year: 255
# Current year: 256
# Current year: 257
# Current year: 258
# Current year: 259
# Current year: 260
# Current year: 261
# Current year: 262
# Current year: 263
# Current year: 264
# Current year: 265
# Current year: 266
# Current year: 267
# Current year: 268
# Current year: 269
# Current year: 270
# Current year: 271
# Current year: 272
# Current year: 273
# Current year: 274
# Current year: 275
# Current year: 276
# Current year: 277
# Current year: 278
# Current year: 279
# Current year: 280
# Current year: 281
# Current year: 282
# Current year: 283
# Current year: 284
# Current year: 285
# Current year: 286
# Current year: 287
# Current year: 288
# Current year: 289
# Current year: 290
# Current year: 291
# Current year: 292
# Current year: 293
# Current year: 294
# Current year: 295
# Current year: 296
# Current year: 297
# Current year: 298
# Current year: 299
# Current year: 300
# saved ./rk_decomp_cloud/rk.decomp.CM2.1p1.+1%solar.50yrref.251-300.nc
# Elapsed time: 2.52 minutes
# CM2.1p1 CTL1860_p2pctSolar_tigercpu_intelmpi_18_80PE
# reading in data...
# interpolating...
# decomposing with radiative kernel...
# [ 101  102  103  104  105  106  107  108  109  110  111  112  113  114
#   115  116  117  118  119  120  121  122  123  124  125  126  127  128
#   129  130  131  132  133  134  135  136  137  138  139  140  141  142
#   143  144  145  146  147  148  149  150  151  152  153  154  155  156
#   157  158  159  160  161  162  163  164  165  166  167  168  169  170
#   171  172  173  174  175  176  177  178  179  180  181  182  183  184
#   185  186  187  188  189  190  191  192  193  194  195  196  197  198
#   199  200  201  202  203  204  205  206  207  208  209  210  211  212
#   213  214  215  216  217  218  219  220  221  222  223  224  225  226
#   227  228  229  230  231  232  233  234  235  236  237  238  239  240
#   241  242  243  244  245  246  247  248  249  250  251  252  253  254
#   255  256  257  258  259  260  261  262  263  264  265  266  267  268
#   269  270  271  272  273  274  275  276  277  278  279  280  281  282
#   283  284  285  286  287  288  289  290  291  292  293  294  295  296
081 1082 1083 1084 1085 1086 1087 1088 1089 1090 1091 1092 1093 1094
#  1095 1096 1097 1098 1099 1100]
# Start year: 101
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.101-150.nc']
# Start year: 151
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.151-200.nc']
# Start year: 201
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.201-250.nc']
# Start year: 251
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.251-300.nc']
# Start year: 301
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.301-350.nc']
# Start year: 351
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.351-400.nc']
# Start year: 401
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.401-450.nc']
# Start year: 451
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.451-500.nc']
# Start year: 501
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.501-550.nc']
# Start year: 551
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.551-600.nc']
# Start year: 601
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.601-650.nc']
# Start year: 651
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.651-700.nc']
# Start year: 701
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.701-750.nc']
# Start year: 751
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.751-800.nc']
# Start year: 801
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.801-850.nc']
# Start year: 851
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.851-900.nc']
# Start year: 901
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.901-950.nc']
# Start year: 951
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.951-1000.nc']
# Start year: 1001
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.1001-1050.nc']
# Start year: 1051
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+2%solar.50yrref.1051-1100.nc']
# CM2.1p1 CTL1860_p4pctSolar_tigercpu_intelmpi_18_80PE
# reading in data...
# interpolating...
# decomposing with radiative kernel...
# [ 101  102  103 ... 1998 1999 2000]
# Start year: 101
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.101-150.nc']
# Start year: 151
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.151-200.nc']
# Start year: 201
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.201-250.nc']
# Start year: 251
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.251-300.nc']
# Start year: 301
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.301-350.nc']
# Start year: 351
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.351-400.nc']
# Start year: 401
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.401-450.nc']
# Start year: 451
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.451-500.nc']
# Start year: 501
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.501-550.nc']
# Start year: 551
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.551-600.nc']
# Start year: 601
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.601-650.nc']
# Start year: 651
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.651-700.nc']
# Start year: 701
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.701-750.nc']
# Start year: 751
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.751-800.nc']
# Start year: 801
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.801-850.nc']
# Start year: 851
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.851-900.nc']
# Start year: 901
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.901-950.nc']
# Start year: 951
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.951-1000.nc']
# Start year: 1001
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1001-1050.nc']
# Start year: 1051
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1051-1100.nc']
# Start year: 1101
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1101-1150.nc']
# Start year: 1151
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1151-1200.nc']
# Start year: 1201
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1201-1250.nc']
# Start year: 1251
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1251-1300.nc']
# Start year: 1301
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1301-1350.nc']
# Start year: 1351
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1351-1400.nc']
# Start year: 1401
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1401-1450.nc']
# Start year: 1451
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1451-1500.nc']
# Start year: 1501
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1501-1550.nc']
# Start year: 1551
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1551-1600.nc']
# Start year: 1601
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1601-1650.nc']
# Start year: 1651
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1651-1700.nc']
# Start year: 1701
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1701-1750.nc']
# Start year: 1751
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1751-1800.nc']
# Start year: 1801
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1801-1850.nc']
# Start year: 1851
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1851-1900.nc']
# Start year: 1901
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1901-1950.nc']
# Start year: 1951
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+4%solar.50yrref.1951-2000.nc']
# CM2.1p1 CTL1860_p6pctSolar_tigercpu_intelmpi_18_80PE
# reading in data...
# interpolating...
# decomposing with radiative kernel...
# [101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118
#  119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 134 135 136
#  137 138 139 140 141 142 143 144 145 146 147 148 149 150 151 152 153 154
#  155 156 157 158 159 160 161 162 163 164 165 166 167 168 169 170 171 172
#  173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190
#  191 192 193 194 195 196 197 198 199 200 201 202 203 204 205 206 207 208
#  209 210 211 212 213 214 215 216 217 218 219 220 221 222 223 224 225 226
#  227 228 229 230 231 232 233 234 235 236 237 238 239 240 241 242 243 244
#  245 246 247 248 249 250 251 252 253 254 255 256 257 258 259 260 261 262
#  263 264 265 266 267 268 269 270 271 272 273 274 275 276 277 278 279 280
#  281 282 283 284 285 286 287 288 289 290 291 292 293 294 295 296 297 298
#  299 300 301 302 303 304 305 306 307 308 309 310]
# Start year: 101
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+6%solar.50yrref.101-150.nc']
# Start year: 151
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+6%solar.50yrref.151-200.nc']
# Start year: 201
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+6%solar.50yrref.201-250.nc']
# Start year: 251
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+6%solar.50yrref.251-300.nc']
# Start year: 301
# Already exists: ['./rk_decomp_cloud/rk.decomp.CM2.1p1.+6%solar.50yrref.301-310.nc']

# %% [markdown]
# ### Continue to 2_compute_plot_total_feedback_cloud and 2_plot_feedback_decomp_GFDL_cloud.
